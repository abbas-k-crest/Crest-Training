# %%
2==2
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
1 != 2
# Out:
# True

# %%
2 >3
# Out:
# False

# %%
2 <3
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
2 <=2
# Out:
# True

# %%
 2 < 2
# Out:
# False
