# %%
pwd
# Out:
# 'c:\\Crest Taining\\01-Python-Bootcamp\\14 - Advanced Python Modules'

# %%
with open("practice.txt","w") as f:
    f.write("This is a text string")

# %%
 import os

# %%
os.getcwd()
# Out:
# 'c:\\Crest Taining\\01-Python-Bootcamp\\14 - Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '104 - Python Collections Module.ipynb',
#  '105 - Opening and Reading Files and Folders Python OS Module.ipynb',
#  '106 - Python Datetime Module.ipynb',
#  '107 - Python Math and Random Modules.ipynb',
#  '108 - Python Debugger.ipynb',
#  '109 - Python Regular Expressions Part One.ipynb',
#  '110 - Python Regular Expressions Part Two.ipynb',
#  '111 - Python Regular Expressions Part Three.ipynb',
#  'practice.txt']

# %%
os.listdir('C:\\Users')
# Out:
# ['AbbasKothari',
#  'All Users',
#  'CIPLADMIN',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Public']

# %%
import shutil

# %%
shutil.move('practice.txt', 'C:\\Crest Taining\\01-Python-Bootcamp')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 shutil.move('practice.txt', 'C:\\Crest Taining\\01-Python-Bootcamp')
#
# File c:\Users\AbbasKothari\anaconda3\Lib\shutil.py:854, in move(src, dst, copy_function)
#     851     real_dst = os.path.join(dst, _basename(src))
#     853     if os.path.exists(real_dst):
# --> 854         raise Error("Destination path '%s' already exists" % real_dst)
#     855 try:
#     856     os.rename(src, real_dst)
#
# Error: Destination path 'C:\Crest Taining\01-Python-Bootcamp\practice.txt' already exists

# %%
for folder, sub_folers, files in os.walk('C:\\Crest Taining\\01-Python-Bootcamp'):
    print(folder)
# Out:
# C:\Crest Taining\01-Python-Bootcamp
# C:\Crest Taining\01-Python-Bootcamp\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\04 - Python Comparison Operators
# C:\Crest Taining\01-Python-Bootcamp\04 - Python Comparison Operators\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\05 - Python Statements
# C:\Crest Taining\01-Python-Bootcamp\05 - Python Statements\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\06 - Methods and Functions
# C:\Crest Taining\01-Python-Bootcamp\06 - Methods and Functions\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\07 - Milestone Project 1
# C:\Crest Taining\01-Python-Bootcamp\07 - Milestone Project 1\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\08 - Object Oriented Programming
# C:\Crest Taining\01-Python-Bootcamp\08 - Object Oriented Programming\.ipynb_checkpoints
# C:\Crest Taining\01-Python-Bootcamp\09 - Modules and Packages
# C:\Crest Taining\01-Python-Bootcamp\09 - Modules and Packages\.ipynb_checkpoints
# ...

# %%
str = "This is the text for the write function to write it in the file using operator"
