# %%
import re

# %%
phrase = "This the number 5 and number 9 to prove the string is executing 4 for number 9 and the or if else while"

# %%
pattern = r'[\d]+'
all = re.findall(pattern, phrase)

# %%
all
# Out:
# ['5', '9', '4', '9']

# %%
re.findall(pattern, phrase)
# Out:
# ['5', '9', '4', '9']

# %%
pattern = r'[\w]+'

# %%
result = re.findall(pattern, phrase)

# %%
result
# Out:
# ['This',
#  'the',
#  'number',
#  '5',
#  'and',
#  'number',
#  '9',
#  'to',
#  'prove',
#  'the',
#  'string',
#  'is',
#  'executing',
#  '4',
#  'for',
#  'number',
#  '9',
#  'and',
#  'the',
#  'or',
#  'if',
#  'else',
#  'while']
