# %% [markdown]
# # Collections

# %%
from collections import Counter

# %%
list1 = [1,2,3,4,5,6,6,7,6,5,4,4,3,32,2,1,1,12,2,33,3]

# %%
Counter(list1)
# Out:
# Counter({1: 3, 2: 3, 3: 3, 4: 3, 6: 3, 5: 2, 7: 1, 32: 1, 12: 1, 33: 1})

# %%
Counter("aaaaaabhadbchwbdhvhdhavhjawvirh viuwrv h w vhwbaoub ")
# Out:
# Counter({'a': 10,
#          'h': 9,
#          'v': 6,
#          'b': 5,
#          'w': 5,
#          ' ': 5,
#          'd': 3,
#          'i': 2,
#          'r': 2,
#          'u': 2,
#          'c': 1,
#          'j': 1,
#          'o': 1})

# %%
text = "This is the sentence to get the idea of how many times a word appear in the sentence"

# %%
Counter(text)
# Out:
# Counter({' ': 17,
#          'e': 13,
#          't': 8,
#          'n': 6,
#          'h': 5,
#          'i': 5,
#          's': 5,
#          'a': 5,
#          'o': 4,
#          'c': 2,
#          'd': 2,
#          'w': 2,
#          'm': 2,
#          'r': 2,
#          'p': 2,
#          'T': 1,
#          'g': 1,
#          'f': 1,
#          'y': 1})

# %%
lst = text.split()

# %%
Counter(lst)
# Out:
# Counter({'the': 3,
#          'sentence': 2,
#          'This': 1,
#          'is': 1,
#          'to': 1,
#          'get': 1,
#          'idea': 1,
#          'of': 1,
#          'how': 1,
#          'many': 1,
#          'times': 1,
#          'a': 1,
#          'word': 1,
#          'appear': 1,
#          'in': 1})
