# %%
import re

# %%
text = "My phonw number is 9976734526"

# %%
phone = re.search('\d\d', text)

# %%
print(phone)
# Out:
# <re.Match object; span=(19, 21), match='99'>

# %%
phone = re.search('\d{10}', text)

# %%
phone
# Out:
# <re.Match object; span=(19, 29), match='9976734526'>

# %%
word = re.search('\w{4}', text)

# %%
word
# Out:
# <re.Match object; span=(3, 7), match='phon'>

# %%
word = re.search('o*a', text)

# %%
word

# %%
phone_number = "444-555-6666"

ph = re.compile('(\d{3})-(\d{3})-(\d{4})')

# %%
result = re.search(ph, phone_number)

# %%
result
# Out:
# <re.Match object; span=(0, 12), match='444-555-6666'>

# %%
result.group()
# Out:
# '444-555-6666'

# %%
result.group(1)
# Out:
# '444'

# %%
result.group(2)
# Out:
# '555'

# %%
result.group(4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 result.group(4)
#
# IndexError: no such group
