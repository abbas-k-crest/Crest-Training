# %% [markdown]
# # Python Debugger

# %%
x = [1,2, 3]

# %%
y = 2
z = 3

# %%
result = y + z

result2 = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 result = y + z
# ----> 3 result2 = x + y
#
# TypeError: can only concatenate list (not "int") to list

# %%
import pdb

# %%
x = [1,2, 3]
y = 2
z = 3

result1 = y + z

pdb.set_trace()

result2 = x + y
# Out:
# > c:\users\abbaskothari\appdata\local\temp\ipykernel_11800\2390749259.py(7)<module>()
# ipdb>
# ipdb>  x
# [1, 2, 3]
# ipdb>  y
# 2
# ipdb>  z
# 3
# ipdb>  result2
# *** NameError: name 'result2' is not defined
# ipdb>  result1
# 5
# ipdb>  c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5 result1 = y + z
#       7 pdb.set_trace()
# ----> 9 result2 = x + y
#
# TypeError: can only concatenate list (not "int") to list
