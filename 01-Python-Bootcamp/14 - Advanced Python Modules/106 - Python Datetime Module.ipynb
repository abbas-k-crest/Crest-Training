# %%
import datetime

# %%
mytime = datetime.time()

# %%
print(mytime)
# Out:
# 00:00:00

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 1, 9, 17, 27, 48, 934097)

# %%
mytime.microsecond
# Out:
# 0

# %%
from datetime import timezone

# %%
timezone()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 timezone()
#
# TypeError: timezone() missing required argument 'offset' (pos 1)

# %%
datetime.datetime(2020,5,3)
# Out:
# datetime.datetime(2020, 5, 3, 0, 0)

# %%
datetime.date.today()
# Out:
# datetime.date(2026, 1, 9)

# %%
datetime.time()
# Out:
# datetime.time(0, 0)

# %%
from datetime import date

# %%
date1 = date(2021, 10, 1)
date2 = date(2021,10,31)

result = date2-date1

# %%
print(result)
# Out:
# 30 days, 0:00:00

# %%
from datetime import datetime

dt1 = datetime(2021,10,3)
dt2 = datetime(2020,10,3)

diff = dt1 -dt2
diff
# Out:
# datetime.timedelta(days=365)
