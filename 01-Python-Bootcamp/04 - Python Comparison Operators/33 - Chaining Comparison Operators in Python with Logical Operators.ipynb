# %% [markdown]
# # LOGICAL OPERATOR

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
1 < 2 or 2 > 3
# Out:
# True

# %%
1 < 2 and not 2 > 3
# Out:
# True
