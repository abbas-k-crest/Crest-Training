# %% [markdown]
# # Tuples

# %%
my_tuple = (1,2,3)

# %%
my_list = [1,2,3]

# %%
type(my_tuple)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
len(my_tuple)
# Out:
# 3

# %%
my_tuple = ('one', 2, 3)

# %%
my_tuple
# Out:
# ('one', 2, 3)

# %%
my_tuple[0]
# Out:
# 'one'

# %%
my_tuple[-1]
# Out:
# 3

# %%
t = (1, 2, 3, 4, 4, 3, 2, 1, 6, 7, 8, 9)

# %%
t.count(3)
# Out:
# 2

# %%
t.index(3) # returns first index of match
# Out:
# 2

# %% [markdown]
# Tuple is Imutable

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_tuple
# Out:
# ('one', 2, 3)

# %%
my_list[0] = "new"

# %%
my_list
# Out:
# ['new', 2, 3]

# %%
my_tuple[0] = "new"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_tuple[0] = "new"
#
# TypeError: 'tuple' object does not support item assignment
