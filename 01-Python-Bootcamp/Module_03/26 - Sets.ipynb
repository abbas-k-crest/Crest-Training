# %% [markdown]
# # Sets

# %% [markdown]
# Unordered & Unique

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset.add(3)

# %%
myset.add(4)

# %%
myset
# Out:
# {1, 2, 3, 4}

# %%
# Trying to add duplicate value
myset.add(1)

# %%
myset
