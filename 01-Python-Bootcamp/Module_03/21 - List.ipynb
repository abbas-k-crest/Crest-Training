# %% [markdown]
# # List

# %% [markdown]
# Ordered Mutable

# %%
my_list = [1,2,3,4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list[1:]
# Out:
# [2, 3, 4]

# %%
my_list[::-1]
# Out:
# [4, 3, 2, 1]

# %%
list_1 = ['a', 'b']

# %%
# concatinate

# %%
concat = my_list + list_1

# %%
concat
# Out:
# [1, 2, 3, 4, 'a', 'b']

# %% [markdown]
# Can Mutate

# %%
new_list = ['one', 'two','three','four']

# %%
new_list[0] = new_list[0].upper()

# %%
new_list
# Out:
# ['ONE', 'two', 'three', 'four']

# %%
new_list.append('Five')

# %%
new_list
# Out:
# ['ONE', 'two', 'three', 'four', 'Five']

# %%
new_list.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
new_list.pop()
# Out:
# 'Five'

# %%
new_list
# Out:
# ['ONE', 'two', 'three', 'four']

# %%
new_list.pop(2)
# Out:
# 'three'

# %%
new_list
# Out:
# ['ONE', 'two', 'four']

# %%
my_list = [1,5,2,6,3,8,4, -3, 6, 9, 10]

# %%
my_list
# Out:
# [1, 5, 2, 6, 3, 8, 4, -3, 6, 9, 10]

# %%
my_list.sort()

# %%
my_list
# Out:
# [-3, 1, 2, 3, 4, 5, 6, 6, 8, 9, 10]

# %%
sorted_list = my_list.sort()

# %%
sorted_list

# %%
type(sorted_list)
# Out:
# NoneType

# %%
my_list.reverse()

# %%
my_list
# Out:
# [10, 9, 8, 6, 6, 5, 4, 3, 2, 1, -3]
