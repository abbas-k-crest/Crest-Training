# %% [markdown]
# # Dicitonary

# %% [markdown]
# Key value pair \n
# Unordered and cannot be sorted

# %%
my_dict = {
    'key1': 'value1',
    'key2': 'value2'
}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_loopup = {
    'apple': 45,
    'orange': 55,
    'milk': 60,
    'paratha': 20
}

# %%
prices_loopup['milk']
# Out:
# 60

# %%
my_dict = {
    'dict1': {
        'key1': 1,
        'key2': 2
    },
    'list': [1,2,3,4,5]
}

# %%
my_dict['list']
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Update Value

# %%
my_dict['list'][0] = "new value in list"

# %%
my_dict
# Out:
# {'dict1': {'key1': 1, 'key2': 2}, 'list': ['new value in list', 2, 3, 4, 5]}

# %%
my_dict['list']
# Out:
# ['new value in list', 2, 3, 4, 5]

# %% [markdown]
# Add new key

# %%
my_dict['new_key'] = "New Key value"

# %%
my_dict
# Out:
# {'dict1': {'key1': 1, 'key2': 2},
#  'list': ['new value in list', 2, 3, 4, 5],
#  'new_key': 'New Key value'}

# %%
len(my_dict)
# Out:
# 3

# %% [markdown]
# #### Methods

# %%
my_dict.keys()
# Out:
# dict_keys(['dict1', 'list', 'new_key'])

# %%
my_dict.values()
# Out:
# dict_values([{'key1': 1, 'key2': 2}, ['new value in list', 2, 3, 4, 5], 'New Key value'])
