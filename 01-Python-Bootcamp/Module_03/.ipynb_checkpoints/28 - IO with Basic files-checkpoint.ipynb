# %%
# %%writefile myfile.txt
# Hello this is a text file
# I'm testing it
# Do not worry
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 myfile = open('wrong.txt')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wrong.txt'

# %%
pwd
# Out:
# 'C:\\Crest Taining\\01-Python-Bootcamp\\Module_03'

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
myfile.read()
# Out:
# "Hello this is a text file\nI'm testing it\nDo not worry\n"

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# Reset cursor before reading again

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# "Hello this is a text file\nI'm testing it\nDo not worry\n"

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n', "I'm testing it\n", 'Do not worry\n']

# %%
myfile.close()

# %%
with open('myfile.txt') as file:
    print(file.readlines())
# Out:
# ['Hello this is a text file\n', "I'm testing it\n", 'Do not worry\n']

# %%
with open('myfile.txt', "w") as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[16], line 2
#       1 with open('myfile.txt', "w") as file:
# ----> 2     content = file.read()
#
# UnsupportedOperation: not readable

# %%
with open('myfile.txt', "a") as file:
    file.write("\nHello This is appended text")

# %%
with open('myfile.txt', "r") as file:
    print(file.read())
# Out:
# Hello This is appended textHello This is appended text
# Hello This is appended text
# Hello This is appended text

# %%
content
# Out:
# 'Hello This is appended text'

# %%
with open('xyz.txt', "w") as file:
    file.write("I created this file")

# %%
with open('xyz.txt', 'r') as file:
    print(file.read())
# Out:
# I created this file
