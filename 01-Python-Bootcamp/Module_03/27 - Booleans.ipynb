# %% [markdown]
# # Boolean

# %% [markdown]
# Convey True or False

# %%
flag = True

# %%
flag
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
1>2
# Out:
# False

# %%
1 ==1
# Out:
# True

# %%
 'one' == 1
# Out:
# False

# %%
type(False)
# Out:
# bool
