# %% [markdown]
# ## If Statement

# %%
hungry = True

# %%
if hungry:
    print("Yes Hungry")
# Out:
# Yes Hungry

# %%
location = "Bank"

# %%
if location == "Bridge":
    print("Its there")
else:
    print("I don't know much")
# Out:
# I don't know much

# %%
if location == "Bridge":
    print("Its there")
elif location == "Bank":
    print("There is no bank in this city")
else:
    print("I don't know much")
# Out:
# There is no bank in this city
