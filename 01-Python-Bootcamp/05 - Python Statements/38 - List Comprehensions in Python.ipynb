# %%
x = 'Hello World'

# %%
mylist = []

for i in x:
    mylist.append(i)

# %%
mylist
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
my_list = [letter for letter in mylist]
my_list
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
list1 = [1,2,3,4,5,6]

square = [num ** 2 for num in list1]
square
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
evensquare = [num ** 2 for num in list1 if num % 2 ==0]
evensquare
# Out:
# [4, 16, 36]
