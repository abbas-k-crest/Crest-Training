# %% [markdown]
# # Advance Strings

# %%
s = "hello World"

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.count('o')
# Out:
# 2

# %%
s
# Out:
# 'hello World'

# %%
s.center(20, '-')
# Out:
# '----hello World-----'

# %%
print('hello\thi')
# Out:
# hello	hi

# %%
s = "Hello"
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# True

# %%
s = "hello there"
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.endswith('o')
# Out:
# False

# %%
s.endswith('e')
# Out:
# True

# %%
s.split()
# Out:
# ['hello', 'there']

# %%
s.split('e')
# Out:
# ['h', 'llo th', 'r', '']

# %%
s.partition('e')
# Out:
# ('h', 'e', 'llo there')
