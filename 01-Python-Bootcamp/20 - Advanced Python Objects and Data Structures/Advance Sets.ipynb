# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s.add(3)

# %%
s.add(1)

# %%
s
# Out:
# {1, 2, 3}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {1,2,3,4,5,6,7,8}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
sc = s.copy()

# %%
s.add(11)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 11}

# %%
sc
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s.difference(sc)
# Out:
# {11}

# %%
s1 = {1,2,3}
s2 = {1,4,5}

s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s2
# Out:
# {1, 4, 5}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 11}

# %%
s.discard(2)

# %%
s.discard(22)

# %%
s
# Out:
# {1, 3, 4, 5, 6, 7, 8, 11}

# %%
 s1.intersection(s2)
# Out:
# set()

# %%
s1 = {1,2,3}
s2 = {1,4,5}

s1.intersection(s2)
# Out:
# {1}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1}

# %%
s1 = {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1.issubset(s2)
# Out:
# True
