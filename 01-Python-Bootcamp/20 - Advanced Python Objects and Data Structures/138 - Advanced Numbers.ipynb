# %% [markdown]
# # Advance Numbers

# %%
hex(455)
# Out:
# '0x1c7'

# %%
bin(455)
# Out:
# '0b111000111'

# %%
hex(512)
# Out:
# '0x200'

# %%
bin(512)
# Out:
# '0b1000000000'

# %%
bin(7)
# Out:
# '0b111'

# %%
2**3
# Out:
# 8

# %%
pow(8, 2)
# Out:
# 64

# %%
pow(8,2,3)
# Out:
# 1

# %%
abs(2-7)
# Out:
# 5

# %%
round(45.26)
# Out:
# 45

# %%
round(78.9)
# Out:
# 79

# %%
round(45.23658954, 2)
# Out:
# 45.24
