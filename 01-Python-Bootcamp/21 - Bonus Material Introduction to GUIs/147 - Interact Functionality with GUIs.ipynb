# %%
import ipywidgets as widgets
from IPython.display import display

# %%
w = widgets.IntSlider()

display(w)
# Out:
# IntSlider(value=0)

# %%
w.layout.margin = 'auto'
w.layout.height = '75px'

# %%
w
# Out:
# IntSlider(value=0, layout=Layout(height='75px', margin='auto'))

# %%
b1 = widgets.Button(description='Ordinary Button', buton_style='info')

# %%
b1.style.button_color = 'red'

# %%
b1
# Out:
# Button(description='Ordinary Button', style=ButtonStyle(button_color='red'))

# %%
b1.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'button_color',
#  'font_family',
#  'font_size',
#  'font_style',
#  'font_variant',
#  'font_weight',
#  'text_color',
#  'text_decoration']

# %%
s1 = widgets.IntSlider(description='My Handle')
s1.style.handle_color = 'black'

s1
# Out:
# IntSlider(value=0, description='My Handle', style=SliderStyle(handle_color='black'))
