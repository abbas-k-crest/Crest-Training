# %% [markdown]
# ## OS Info and Directory Listing

# %%
import os

# %%
print("operating system:", os.name)
# Out:
# operating system: nt

# %%
if hasattr(os, 'uname'):
    print("\nInformation of current operating system:", os.uname())
else:
    print("os.uname() is not available")
# Out:
# os.uname() is not available

# %%
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: C:\Crest Taining\02-Python Practice\W3resource\11 Python Modules

# %%
print("List of files and Directory:")

print(os.listdir('.'))
# Out:
# List of files and Directory:
# ['.ipynb_checkpoints', '01 BuiltIN.ipynb', 'Untitled.ipynb']

# %%
print("\nTest if a specified file exists or not:")
filename = 'abc.txt'

try:
    with open(filename, 'r') as f:
        text = f.read()
        print(f"\nContents of '{filename}':\n{text}")
except IOError:
    print(f"\nFile '{filename}' does not exist or could not be read.")
# Out:
# Test if a specified file exists or not:
#
# File 'abc.txt' does not exist or could not be read.
