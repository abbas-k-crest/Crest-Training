# %% [markdown]
# ## Increment Memory View Elements

# %%
del memoryview
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 del memoryview
#
# NameError: name 'memoryview' is not defined

# %%
def test(memory):

    for i in range(len(memory)):
        memory[i] = (memory[i] + 10) % 256

# %%
data = bytearray([100, 200, 150, 30, 50])
memory = memoryview(data)

# %%
print(list(memory))
# Out:
# [100, 200, 150, 30, 50]
