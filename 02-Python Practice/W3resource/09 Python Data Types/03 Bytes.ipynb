# %% [markdown]
# ## Bytearray Creation from List

# %%
def byte_array(lst):
    return bytearray(lst)

# %%
lst = [72, 36, 84, 96, 108, 12, 24, 60, 48, 120]

# %%
print(byte_array(lst))
# Out:
# bytearray(b'H$T`l\x0c\x18<0x')
