# %% [markdown]
# ## Frozenset of squares of odd numbers

# %%
def frozen_set(n):
    return frozenset({x**2 for x in range(1, n, 2)})

# %%
n = 10

# %%
frozen_set(n)
# Out:
# frozenset({1, 9, 25, 49, 81})
