# %% [markdown]
# ## Multi-threaded factorial calculation

# %%
import threading

# %%
def factorial_of_a_number(n):
    result = 1

    for i in range(1, n+1):
        result *= i

    return result

# %%
def calculate_factorial(n):
    print(f"\nCalculating factorial of {n} in thread {threading.current_thread().name}")
    result = factorial_of_a_number(n)
    print(f"Factorial of {n} is {result} in thread {threading.current_thread().name}")

# %%
n = 12

# %%
thread1 = threading.Thread(target=calculate_factorial, args=(n,))
thread2 = threading.Thread(target=calculate_factorial, args=(n,))

# %%
thread1.start()
thread2.start()

thread1.join()
thread2.join()
# Out:
# Calculating factorial of 12 in thread Thread-7 (calculate_factorial)
# Calculating factorial of 12 in thread Thread-8 (calculate_factorial)
# Factorial of 12 is 479001600 in thread Thread-8 (calculate_factorial)
#
# Factorial of 12 is 479001600 in thread Thread-7 (calculate_factorial)
