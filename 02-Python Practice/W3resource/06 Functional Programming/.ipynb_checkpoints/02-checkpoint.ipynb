# %% [markdown]
# ## Anagram Finder Lambda

# %%
from collections import Counter

# %%
l = ['abc','bac','lil','bro','cab']
s = 'abc'

# %%
list(filter(lambda x: Counter(s) == Counter(x), l))
# Out:
# ['abc', 'bac', 'cab']
