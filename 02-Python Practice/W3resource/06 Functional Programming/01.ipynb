# %% [markdown]
# ## Check if a Number is Perfect

# %%
def is_perfect(n):
    divisors = []

    for i in range(1, n//2+1):
        if n%i == 0:
            divisors.append(i)
    return sum(divisors) == n

# %%
n = 8128

# %%
is_perfect(n)
# Out:
# True

# %%
is_perfect(16)
# Out:
# False
