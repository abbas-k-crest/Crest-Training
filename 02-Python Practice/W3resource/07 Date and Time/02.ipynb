# %% [markdown]
# ## Check for Leap Year:

# %%
pip install pendulum
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pendulum
import calendar

# %%
curr_year = pendulum.now().year

# %%
curr_year
# Out:
# 2026

# %%
is_leap_year = calendar.isleap(curr_year)

# %%
is_leap_year
# Out:
# False

# %% [markdown]
# ## Is it Weekday or Weekend?

# %%
def isweekday(d):
    if d >= 1 and d <= 5:
        print("It's a weekday")
    else:
        print("Weekend!!")

# %%
isweekday(pendulum.now().day_of_week)
# Out:
# It's a weekday

# %%
pendulum.now().day_of_week
# Out:
# <WeekDay.FRIDAY: 4>

# %%
pendulum.now()
# Out:
# DateTime(2026, 1, 16, 13, 34, 9, 829353, tzinfo=Timezone('Asia/Calcutta'))

# %%
dt = pendulum.date(2026, 1, 13)
print(dt.day_of_week)
# Out:
# 1

# %%
dt.day
# Out:
# 13
