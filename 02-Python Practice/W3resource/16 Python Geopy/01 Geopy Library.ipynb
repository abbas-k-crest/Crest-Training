# %% [markdown]
# ## Find the latitude and longitude of a given location

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
#
#    -------------------- ------------------- 1/2 [geopy]
#    -------------------- ------------------- 1/2 [geopy]
#    ---------------------------------------- 2/2 [geopy]
#
# Successfully installed geographiclib-2.1 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="geoapiExercises")

addyesses = [
    "27488 Stanford Avenue, North Dakota",
    "380 New York St, Redlands, CA 92373",
    "1600 Pennsylvania Avenue NW"
]

for addy in addyesses:
    print("\nLocation addyess:", addy)
    try:
        location = geolocator.geocode(addy, timeout=10)
        if location:
            print("Latitude and Longitude of the said addyess:")
            print((location.latitude, location.longitude))
        else:
            print("Location not found.")
    except Exception as e:
        print(f"Error occurred while geocoding: {e}")
# Out:
# Location addyess: 27488 Stanford Avenue, North Dakota
# Error occurred while geocoding: Non-successful status code 403
#
# Location addyess: 380 New York St, Redlands, CA 92373
# Error occurred while geocoding: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=380+New+York+St%2C+Redlands%2C+CA+92373&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=10)"))
#
# Location addyess: 1600 Pennsylvania Avenue NW
# Error occurred while geocoding: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=1600+Pennsylvania+Avenue+NW&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=10)"))
