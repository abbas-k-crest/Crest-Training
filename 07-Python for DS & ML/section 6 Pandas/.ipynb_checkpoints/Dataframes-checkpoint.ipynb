# %% [markdown]
# # DataFrames

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(4,3), ['A', 'B', 'C', 'D'], ['X', 'Y', 'Z'])

# %%
df
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df['X']
# Out:
# A    2.706850
# B    0.503826
# C   -0.848077
# D    0.740122
# Name: X, dtype: float64

# %%
df.X
# Out:
# A    2.706850
# B    0.503826
# C   -0.848077
# D    0.740122
# Name: X, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['X'])
# Out:
# pandas.core.series.Series

# %%
df[['X', 'Y']]
# Out:
#           X         Y
# A  2.706850  0.628133
# B  0.503826  0.651118
# C -0.848077  0.605965
# D  0.740122  0.528813

# %%
df['new'] = df['X'] + df['Y']

# %%
df
# Out:
#           X         Y         Z       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112
# D  0.740122  0.528813 -0.589001  1.268936

# %%
df.drop('new', axis=1)
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df
# Out:
#           X         Y         Z       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112
# D  0.740122  0.528813 -0.589001  1.268936

# %%
df.drop('new', axis=1, inplace=True)

# %%
df
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df.drop('D', axis=0)
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168

# %%
df
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df.drop('D', inplace=True)

# %%
df
# Out:
#           X         Y         Z
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168

# %%
df.shape
# Out:
# (3, 3)

# %%
df = pd.DataFrame(randn(4,3), ['A', 'B', 'C', 'D'], ['X', 'Y', 'Z'])

# %%
df
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# B  0.955057  0.190794  1.978757
# C  2.605967  0.683509  0.302665
# D  1.693723 -1.706086 -1.159119

# %%
df.loc['A']
# Out:
# X    0.188695
# Y   -0.758872
# Z   -0.933237
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# X    2.605967
# Y    0.683509
# Z    0.302665
# Name: C, dtype: float64

# %%
df.loc['B','Y']
# Out:
# np.float64(0.19079432237171562)

# %%
df.loc[['A','C'], ['Y','Z']]
# Out:
#           Y         Z
# A -0.758872 -0.933237
# C  0.683509  0.302665

# %% [markdown]
# ### Part 2

# %%
df['X']
# Out:
# A    0.188695
# B    0.955057
# C    2.605967
# D    1.693723
# Name: X, dtype: float64

# %%
df['X'] > 0
# Out:
# A    True
# B    True
# C    True
# D    True
# Name: X, dtype: bool

# %%
df[df['X']>0]
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# B  0.955057  0.190794  1.978757
# C  2.605967  0.683509  0.302665
# D  1.693723 -1.706086 -1.159119

# %%
df[df['Z']<0]
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# D  1.693723 -1.706086 -1.159119

# %%
df[(df['X']>0) & (df['Z']<0)]
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# D  1.693723 -1.706086 -1.159119

# %%
df[(df['X']>0) | (df['Z']<0)]
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# B  0.955057  0.190794  1.978757
# C  2.605967  0.683509  0.302665
# D  1.693723 -1.706086 -1.159119

# %%
df
# Out:
#           X         Y         Z
# A  0.188695 -0.758872 -0.933237
# B  0.955057  0.190794  1.978757
# C  2.605967  0.683509  0.302665
# D  1.693723 -1.706086 -1.159119

# %%
df.reset_index()
# Out:
#   index         X         Y         Z
# 0     A  0.188695 -0.758872 -0.933237
# 1     B  0.955057  0.190794  1.978757
# 2     C  2.605967  0.683509  0.302665
# 3     D  1.693723 -1.706086 -1.159119

# %%
newind = 'CA NY WY OR '.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'OR']

# %%
df['states'] = newind

# %%
df
# Out:
#           X         Y         Z states
# A  0.188695 -0.758872 -0.933237     CA
# B  0.955057  0.190794  1.978757     NY
# C  2.605967  0.683509  0.302665     WY
# D  1.693723 -1.706086 -1.159119     OR

# %%
df.set_index('states')
# Out:
#                X         Y         Z
# states
# CA      0.188695 -0.758872 -0.933237
# NY      0.955057  0.190794  1.978757
# WY      2.605967  0.683509  0.302665
# OR      1.693723 -1.706086 -1.159119

# %%
df
# Out:
#           X         Y         Z states
# A  0.188695 -0.758872 -0.933237     CA
# B  0.955057  0.190794  1.978757     NY
# C  2.605967  0.683509  0.302665     WY
# D  1.693723 -1.706086 -1.159119     OR
