# %%
import pandas as pd

# %%
import numpy as np

# %%
labels = ['a', 'b', 'c']
my_data = [1,2,3]
arr = np.array(my_data)
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=my_data)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(data=my_data, index=labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data = pd.Series(labels)

# %%
data[0]
# Out:
# 'a'

# %%
data = pd.Series(data=my_data, index=labels)

# %%
data['a'].item()
# Out:
# 1

# %%
pd.Series([1,2,3,4,5], ['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
