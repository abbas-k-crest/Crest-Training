# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-6.8.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (4.10.0)
# Collecting audioop-lts<1.0 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==2.2.0 (from gradio)
#   Downloading gradio_client-2.2.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (1.4.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (2.2.6)
# Requirement already satisfied: orjson~=3.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (2.12.4)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio) (0.41.0)
# Requirement already satisfied: fsspec in c:\users\abbaskothari\anaconda3\lib\site-packages (from gradio-client==2.2.0->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\abbaskothari\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users
#    ---------------------------------- ----- 21.0/24.2 MB 694.0 kB/s eta 0:00:05
#    ----------------------------------- ---- 21.5/24.2 MB 708.8 kB/s eta 0:00:04
#    ------------------------------------ --- 21.8/24.2 MB 714.5 kB/s eta 0:00:04
#    ------------------------------------ --- 22.0/24.2 MB 716.7 kB/s eta 0:00:03
#    ------------------------------------ --- 22.0/24.2 MB 716.7 kB/s eta 0:00:03
#    ------------------------------------ --- 22.3/24.2 MB 714.1 kB/s eta 0:00:03
#    ------------------------------------ --- 22.3/24.2 MB 714.1 kB/s eta 0:00:03
#    ------------------------------------- -- 22.5/24.2 MB 716.6 kB/s eta 0:00:03
#    ------------------------------------- -- 22.8/24.2 MB 718.7 kB/s eta 0:00:02
#    -------------------------------------- - 23.1/24.2 MB 723.8 kB/s eta 0:00:02
#    ---------------------------------------  23.6/24.2 MB 735.4 kB/s eta 0:00:01
#    ---------------------------------------  23.6/24.2 MB 735.4 kB/s eta 0:00:01
#    ---------------------------------------  24.1/24.2 MB 742.0 kB/s eta 0:00:01
#    ---------------------------------------  24.1/24.2 MB 742.0 kB/s eta 0:00:01
#    ---------------------------------------  24.1/24.2 MB 742.0 kB/s eta 0:00:01
#    ---------------------------------------- 24.2/24.2 MB 787.6 kB/s  0:00:58
# Downloading gradio_client-2.2.0-py3-none-any.whl (58 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading brotli-1.2.0-cp313-cp313-win_amd64.whl (369 kB)
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, brotli, semantic-version, python-multipart, groovy, ffmpy, audioop-lts, aiofiles, starlette, safehttpx, fastapi, gradio-client, gradio
#
#    ------ ---------------------------------  2/13 [semantic-version]
#    --------------- ------------------------  5/13 [ffmpy]
#    --------------------- ------------------  7/13 [aiofiles]
#    ------------------------ ---------------  8/13 [starlette]
#    ------------------------ ---------------  8/13 [starlette]
#    ------------------------------ --------- 10/13 [fastapi]
#    ------------------------------ --------- 10/13 [fastapi]
#    ------------------------------ --------- 10/13 [fastapi]
#    ------------------------------ --------- 10/13 [fastapi]
#    --------------------------------- ------ 11/13 [gradio-client]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ------------------------------------ --- 12/13 [gradio]
#    ---------------------------------------- 13/13 [gradio]
#
# Successfully installed aiofiles-24.1.0 audioop-lts-0.2.2 brotli-1.2.0 fastapi-0.135.1 ffmpy-1.0.0 gradio-6.8.0 gradio-client-2.2.0 groovy-0.1.2 pydub-0.25.1 python-multipart-0.0.22 safehttpx-0.1.7 semantic-version-2.10.0 starlette-0.52.1

# %%
from groq import Groq
from PyPDF2 import PdfReader
import gradio as gr
import json

# %%
client = Groq()

# %%
reader = PdfReader("Profile.pdf")
linkedin = ""

for page in reader.pages:
    linkedin = page.extract_text()
    if txt:
        linkedin += txt

# %%
print(linkedin)
# Out:
#
# Dubai, United Arab Emirates
# Working as an AI Intern, I designed and implemented an AI-driven workflow
# to automate the RSVP process for the company’s Izzan RSVP WhatsApp
# service.
# The role involved architecting conversational decision flows, intent
# classification, event selection logic, and state management to handle real user
# behaviour across multiple events.
# I built LLM-based systems with strong guardrails to minimise hallucinations
# and ensure reliable, context-aware responses, and deployed the solution using
# Azure cloud services to support scalable, production-ready automation with
# minimal human intervention.
# Education
# A D Patel Institute of Technology, CVM University
# Bachelor of Technology - BTech, Computer science and design  · (2022)
# Burhani English School
# High school
#   Page 2 of 2
# Dubai, United Arab Emirates
# Working as an AI Intern, I designed and implemented an AI-driven workflow
# to automate the RSVP process for the company’s Izzan RSVP WhatsApp
# service.
# The role involved architecting conversational decision flows, intent
# classification, event selection logic, and state management to handle real user
# behaviour across multiple events.
# I built LLM-based systems with strong guardrails to minimise hallucinations
# and ensure reliable, context-aware responses, and deployed the solution using
# Azure cloud services to support scalable, production-ready automation with
# minimal human intervention.
# Education
# A D Patel Institute of Technology, CVM University
# Bachelor of Technology - BTech, Computer science and design  · (2022)
# Burhani English School
# High school
#   Page 2 of 2

# %%
name = "Abbas Kothari"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Abbas Kothari. You are answering questions on Abbas Kothari's website, particularly questions related to Abbas Kothari's career, background, skills and experience. Your responsibility is to represent Abbas Kothari for interactions on the website as faithfully as possible. You are given a summary of Abbas Kothari's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## LinkedIn Profile:\n\xa0 \xa0\nDubai, United Arab Emirates\nWorking as an AI Intern, I designed and implemented an AI-driven workflow\nto automate the RSVP process for the company’s Izzan RSVP WhatsApp\nservice. \nThe role involved architecting conversational decision flows, intent\nclassification, event selection logic, and state management to handle real user\nbehaviour across multiple events.\nI built LLM-based systems with strong guardrails to minimise hallucinations\nand ensure reliable, context-aware responses, and deployed the solution using\nAzure cloud services to support scalable, production-ready automation with\nminimal human intervention.\nEducation\nA D Patel Institute of Technology, CVM University\nBachelor of Technology - BTech,\xa0Computer science and design \xa0·\xa0(2022)\nBurhani English School\nHigh school\xa0\n\xa0 Page 2 of 2\n\nWith this context, please chat with the user, always staying in character as Abbas Kothari."

# %%
def chat(message, history):
    cleaned_history = [
        {"role": msg["role"], "content": msg["content"]}
        for msg in history
    ]

    messages = (
        [{"role": "system", "content": system_prompt}]
        + cleaned_history
        + [{"role": "user", "content": message}]
    )

    response = client.chat.completions.create(
        model="openai/gpt-oss-20b",
        messages=messages
    )

    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    user_prompt += "Only reply i njson with 2 fields: is_acceptable and feedback "
    return user_prompt

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = client.chat.completions.create(model="openai/gpt-oss-20b", messages=messages, response_format={"type": "json_object"})
    return json.loads(response.choices[0].message.content)

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a degree?"}]
response = client.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'Yes, I hold a Bachelor of Technology (B.Tech.) degree in Computer Science and Design, which I earned from the A\u202fD Patel Institute of Technology, CVM University in 2022. I also completed my high school education at Burhani English School.'

# %%
evaluate(reply, "do you hold a degree?", messages[:1])
# Out:
# {'is_acceptable': True,
#  'feedback': 'The response accurately reflects the provided LinkedIn profile and is concise, professional, and appropriate for a potential client or employer.'}

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"

    cleaned_history = [
        {"role": msg["role"], "content": msg["content"]}
        for msg in history
    ]
    
    messages = [{"role": "system", "content": updated_system_prompt}] + cleaned_history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "degree" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt

    cleaned_history = [
        {"role": msg["role"], "content": msg["content"]}
        for msg in history
    ]
    
    messages = [{"role": "system", "content": system}] + cleaned_history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="openai/gpt-oss-20b", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.get("is_acceptable"):
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.get("feedback"))
        reply = rerun(reply, message, history, evaluation.get("feedback"))       
    return reply

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7871
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7871/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The answer is not acceptable: it is written in pig‑latin, is garbled, and does not clearly state the degree earned. It does not address the user’s question in a professional, straightforward manner.
