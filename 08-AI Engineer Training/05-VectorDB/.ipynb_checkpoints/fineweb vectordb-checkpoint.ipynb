# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-4.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (2.2.6)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (4.10.0)
# Requirement already satisfied: certifi in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\abbaskothari\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\abbaskothari\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abbaskothari\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\abbaskothari\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: typer>=0.24.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.2.1)
# Requirement already satisfied: rich>=12.3.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\abbaskothari\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abbaskothari\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abbaskothari\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
# Downloading multiprocess-0.70.18-py313-none-any.whl (151 kB)
# Installing collected packages: multiprocess, datasets
#
#    ---------------------------------------- 0/2 [multiprocess]
#    ---------------------------------------- 0/2 [multiprocess]
#    ---------------------------------------- 0/2 [multiprocess]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    -------------------- ------------------- 1/2 [datasets]
#    ---------------------------------------- 2/2 [datasets]
#
# Successfully installed datasets-4.5.0 multiprocess-0.70.18

# %%
from datasets import load_dataset
from dotenv import load_dotenv, find_dotenv
import pinecone
from pinecone import Pinecone, ServerlessSpec
import os
from sentence_transformers import SentenceTransformer

# %%
fw = load_dataset("HuggingFaceFW/fineweb", name = "sample-10BT", split = "train", streaming = True)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Resolving data files:   0%|          | 0/27468 [00:00<?, ?it/s]

# %%
fw
# Out:
# IterableDataset({
#     features: ['text', 'id', 'dump', 'url', 'date', 'file_path', 'language', 'language_score', 'token_count'],
#     num_shards: 15
# })

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# %load_ext dotenv
# %dotenv

# %%
pc = Pinecone(api_key = os.environ.get("PINECONE_API_KEY"), environment = os.environ.get("PINECONE_ENV"))

# %%
pc.create_index(
    name="text",
    dimension=model.get_sentence_embedding_dimension(),
    metric="cosine",
    spec=ServerlessSpec(
        cloud='aws',
        region='us-east-1'
    )
)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pc.create_index(
#       2     name="text",
#       3     dimension=model.get_sentence_embedding_dimension(),
#       4     metric="cosine",
#       5     spec=ServerlessSpec(
#       6         cloud='aws',
#       7         region='us-east-1'
#       8     )
#       9 )
#
# File ~\anaconda3\Lib\site-packages\pinecone\pinecone.py:499, in Pinecone.create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     378 def create_index(
#     379     self,
#     380     name: str,
#    (...)    387     tags: dict[str, str] | None = None,
#     388 ) -> "IndexModel":
#     389     """Creates a Pinecone index.
#     390
#     391     :param name: The name of the index to create. Must be unique within your project and
#    (...)    497
#     498     """
# --> 499     return self.db.index.create(
#     500         name=name,
#     501         spec=spec,
#     502         dimension=dimension,
#     503         metric=metric,
#     504         timeout=timeout,
#     505         deletion_protection=deletion_protection,
#     506         vector_type=vector_type,
#     507         tags=tags,
#     508     )
#
# File ~\anaconda3\Lib\site-packages\pinecone\utils\require_kwargs.py:26, in require_kwargs.<locals>.wrapper(*args, **kwargs)
#      21     param_names = list(inspect.signature(func).parameters.keys())[1:]  # Skip self
#      22     raise TypeError(
#      23         f"{func.__name__}() requires keyword arguments. "
#      24         f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      25     )
# ---> 26 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pinecone\db_control\resources\sync\index.py:95, in IndexResource.create(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#      73 @require_kwargs
#      74 def create(
#      75     self,
#    (...)     84     tags: dict[str, str] | None = None,
#      85 ) -> IndexModel:
#      86     req = PineconeDBControlRequestFactory.create_index_request(
#      87         name=name,
#      88         spec=spec,
#    (...)     93         tags=tags,
#      94     )
# ---> 95     resp = self._index_api.create_index(create_index_request=req)
#      97     if timeout == -1:
#      98         from typing import cast
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:375, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, x_pinecone_api_version, **kwargs)
#     373 kwargs["x_pinecone_api_version"] = x_pinecone_api_version
#     374 kwargs["create_index_request"] = create_index_request
# --> 375 return cast(IndexModel | ApplyResult[IndexModel], self.call_with_http_info(**kwargs))
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\api_client.py:320, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     299     return self.threadpool_executor.submit(
#     300         self.__call_api,
#     301         resource_path,
#    (...)    316         _check_type,
#     317     )
#     319 if not async_req:
# --> 320     return self.__call_api(
#     321         resource_path,
#     322         method,
#     323         path_params,
#     324         query_params,
#     325         header_params,
#     326         body,
#     327         post_params,
#     328         files,
#     329         response_type,
#     330         auth_settings,
#     331         _return_http_data_only,
#     332         collection_formats,
#     333         _preload_content,
#     334         _request_timeout,
#     335         _host,
#     336         _check_type,
#     337     )
#     339 return self.pool.apply_async(
#     340     self.__call_api,
#     341     (
#    (...)    358     ),
#     359 )
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\api_client.py:185, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
# --> 185     raise e
#     187 self.last_response = response_data
#     189 return_data = response_data
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\api_client.py:173, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     164 url = build_request_url(
#     165     config=config,
#     166     processed_path_params=path_params_tuple,
#     167     resource_path=resource_path,
#     168     _host=_host,
#     169 )
#     171 try:
#     172     # perform request and return response
# --> 173     response_data = self.request(
#     174         method,
#     175         url,
#     176         query_params=processed_query_params,
#     177         headers=headers_tuple,
#     178         post_params=processed_post_params,
#     179         body=body,
#     180         _preload_content=_preload_content,
#     181         _request_timeout=_request_timeout,
#     182     )
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\api_client.py:400, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     390     return self.rest_client.OPTIONS(
#     391         url,
#     392         query_params=query_params,
#    (...)    397         body=body,
#     398     )
#     399 elif method == "POST":
# --> 400     return self.rest_client.POST(
#     401         url,
#     402         query_params=query_params,
#     403         headers=headers,
#     404         post_params=post_params,
#     405         _preload_content=_preload_content,
#     406         _request_timeout=_request_timeout,
#     407         body=body,
#     408     )
#     409 elif method == "PUT":
#     410     return self.rest_client.PUT(
#     411         url,
#     412         query_params=query_params,
#    (...)    417         body=body,
#     418     )
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:270, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     267     # log response body
#     268     logger.debug("response body: %s", r.data)
# --> 270 return raise_exceptions_or_return(r)
#
# File ~\anaconda3\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'vary': 'origin, access-control-request-method, access-control-request-headers', 'access-control-allow-origin': '*', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2025-10', 'x-cloud-trace-context': '3eff187166d2245db5e092b6751fa47c', 'date': 'Tue, 24 Feb 2026 10:33:25 GMT', 'server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
index = pc.Index(name = "text")

# %%
# Define the number of items you want to process (subset size)
subset_size = 1000  # For example, take only 10,000 items

# Iterate over the dataset and prepare data for upserting
vectors_to_upsert = []
for i, item in enumerate(fw):
    if i >= subset_size:
        break

    text = item['text']
    unique_id = str(item['id'])
    language = item['language']

    # Create an embedding for the text
    embedding = model.encode(text, show_progress_bar=False).tolist()

    # Prepare metadata
    metadata = {'language': language}

    # Append the tuple (id, embedding, metadata) to the list
    vectors_to_upsert.append((unique_id, embedding, metadata))

# Upsert data to Pinecone in batches
batch_size = 1000  # Adjust based on your environment and dataset size
for i in range(0, len(vectors_to_upsert), batch_size):
    batch = vectors_to_upsert[i:i + batch_size]
    index.upsert(vectors=batch)

print("Subset of data upserted to Pinecone index.")
# Out:
# Subset of data upserted to Pinecone index.
